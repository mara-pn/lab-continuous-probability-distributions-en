# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns
from scipy.stats import uniform

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# Define the parameters for the uniform distribution
a = 0  # minimum value
b = 1  # maximum value

# Generate a sample from the distribution
sample_size = 3000
data_uniform = uniform.rvs(size=sample_size, loc=a, scale=b-a)

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# function to generate uniformily distributed random numbers

def uni_rand(bottom, ceiling, count):
    return uniform.rvs(loc = bottom, scale = ceiling - bottom, size = count)

# %%
# calling function with given parameters

uni1 = uni_rand(10, 15, 100)
uni2 = uni_rand(10, 60, 1000)

# %%
# Plotting the sample distribution 
plt.hist(uni1, bins=10, density=False, alpha=0.7, color='orange')
plt.title('Uniform Distribution (10,15,100)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.legend()
plt.show()

plt.hist(uni2, bins=10, density=False, alpha=0.7, color='orange')
plt.title('Uniform Distribution (10,15,100)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.legend()
plt.show()
# Out:
# C:\Users\black\AppData\Local\Temp\ipykernel_8800\555997684.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\black\AppData\Local\Temp\ipykernel_8800\555997684.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# the greatest difference is the sample size, but on top of that there is a variation in the value count within the bins as both arrays are randomly filled.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# function to generate normally distributed random numbers

def norm_rand(sample_size, mu, sigma):
    return norm.rvs(size=sample_size, loc=mu, scale=sigma)

# %%
norm1 = norm_rand(1000, 10, 1)
norm2 = norm_rand(1000, 10, 50)

# %%
# Plotting the sample distribution
plt.hist(norm1, bins=50, density=False, alpha=0.6, color='slateblue')
plt.title('Normal Distribution 1')
plt.xlabel('Value')
plt.ylabel('Counts')
plt.show()

plt.hist(norm2, bins=50, density=False, alpha=0.6, color='slateblue')
plt.title('Normal Distribution 2')
plt.xlabel('Value')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# The distribution differ strongly from the spread of their values. The first one only ranges from 7 to 13, whereas the second ranges from -150 to 150. This is due to the difference in the standard deviation. The second is 50 (compared to the first with 1), so the deviation between values is much bigger.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# import dataset
vehicle = pd.read_csv(r"vehicles.csv")

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# plotting histogram (normalized)

data = vehicle["Fuel Barrels/Year"]

plt.hist(data, bins=30, density=True, alpha=0.6, color='slateblue')
plt.title('Histogram: Fuel Barrels/Year')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# %%
# comparisson data to theoretical normal distribution

# mean & std
mean = np.mean(data)
std = np.std(data)

# plotting data 
plt.hist(data, bins=30, density=True, alpha=0.6, color='slateblue')
plt.title('Histogram: Fuel Barrels/Year')
plt.xlabel('Value')
plt.ylabel('Density')

# range of x values
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

# normal PDF with parameters 
p = norm.pdf(x, mean, std)

# plot normal distribution curve
plt.plot(x, p, "k", linewidth = 2)
plt.title('Normal Distribution Fit: Fuel Barrels/Year')
plt.xlabel('Value')
plt.ylabel('Density')

plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# comparisson data to theoretical normal distribution

# data
data = vehicle["CO2 Emission Grams/Mile"]

# mean & std
mean = np.mean(data)
std = np.std(data)

# plotting data 
plt.hist(data, bins=30, density=True, alpha=0.6, color='slateblue')
plt.title('Histogram: CO2 Emission Grams/Mile')
plt.xlabel('Value')
plt.ylabel('Density')

# range of x values
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

# normal PDF with parameters 
p = norm.pdf(x, mean, std)

# plot normal distribution curve
plt.plot(x, p, "k", linewidth = 2)
plt.title('Normal Distribution Fit: CO2 Emission Grams/Mile')
plt.xlabel('Value')
plt.ylabel('Density')

plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
# comparisson data to theoretical normal distribution

# data
data = vehicle["Combined MPG"]

# mean & std
mean = np.mean(data)
std = np.std(data)

# plotting data 
plt.hist(data, bins=30, density=True, alpha=0.6, color='slateblue')
plt.title('Histogram: Combined MPG')
plt.xlabel('Value')
plt.ylabel('Density')

# range of x values
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

# normal PDF with parameters 
p = norm.pdf(x, mean, std)

# plot normal distribution curve
plt.plot(x, p, "k", linewidth = 2)
plt.title('Normal Distribution Fit: Combined MPG')
plt.xlabel('Value')
plt.ylabel('Density')

plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# all of them have a positive skew -> the skew is getting stronger in the order of displayed columns

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# function to generate exponentially distributed random numbers
def exp(mean, size):
    return np.random.exponential(scale=mean, size=size)

# generating number sequences
exp1 = exp(10, 10)
print(exp1)

exp2 = exp(10, 100)
print(exp2)
# Out:
# [ 1.79177889  6.86385766 13.18313616  4.26407857  0.16662301 41.04912593
#   8.30910754 12.09231375  0.60194605  9.55491419]
# [2.86135158e+01 4.35486127e+00 1.75080102e+00 2.99707458e+00
#  4.00798771e+00 1.27281373e+01 7.62840107e+00 1.34974494e+00
#  1.92687888e+00 4.60985999e+00 2.04802772e+01 7.61043166e+01
#  2.98617545e+01 1.05658194e+01 3.65462730e+01 8.48565129e+00
#  1.36286860e+01 3.74999119e+00 6.94772307e-01 6.44699942e+00
#  7.64222511e+00 4.54457485e+00 2.30581496e+00 1.88996355e+00
#  8.63186119e-02 1.61338938e-01 1.50785229e+01 8.74840696e-01
#  2.67428468e+01 2.31010540e+00 1.77506882e+00 5.43603987e+00
#  1.57480600e+01 3.76333935e+00 1.00892791e+01 2.39275717e+01
#  1.09533739e+01 1.69459317e+01 1.91534475e+01 2.88919306e-01
#  7.92364631e+00 8.95079423e+00 1.74711412e+01 9.85913866e+00
#  7.71481460e+00 5.25177488e-01 4.96992208e+00 1.64681045e+00
#  5.08149901e-01 1.47207399e+01 6.90543974e+00 2.15729661e+01
# ...

# %%
# Visualizing 
plt.hist(exp1, bins=100, density=True)
plt.title("exponential distribution size 10")
plt.show()

plt.hist(exp2, bins=100, density=True)
plt.title("exponential distribution size 100")
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# parameters
mean = 10
lam = 1/mean
x = 15

# probability
P = 1 - np.exp(-lam * x)

print("Probabaility of a customer spending less than 15 min in the bank is:", round(P*100), "%")
# Out:
# Probabaility of a customer spending less than 15 min in the bank is: 78 %

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
P = np.exp(-lam * x)
print("Probabaility of a customer spending more than 15 min in the bank is:", round(P*100), "%")
# Out:
# Probabaility of a customer spending more than 15 min in the bank is: 22 %

# %%
# OR:

P = 1- (1 - np.exp(-lam * x))
print("Probabaility of a customer spending more than 15 min in the bank is:", round(P*100), "%")
# Out:
# Probabaility of a customer spending more than 15 min in the bank is: 22 %
